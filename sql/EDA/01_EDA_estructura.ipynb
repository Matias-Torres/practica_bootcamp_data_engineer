-- %%
%sql
-- Tamaño del Dataset
SELECT 
  COUNT(*) AS total_propiedades 
FROM bootcamp_matias.raw.propiedades_bronze

-- %%
%sql 
-- Estrucutra del dataset
DESCRIBE bootcamp_matias.raw.propiedades_bronze

-- %%
%sql
--Muestra de datos
SELECT * FROM bootcamp_matias.raw.propiedades_bronze LIMIT 10
