-- %%
%sql
DROP TABLE IF EXISTS bootcamp_matias.gold.dim_estado;

CREATE TABLE bootcamp_matias.gold.dim_estado(
  estado_id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
  estado STRING NOT NULL,
  _created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
)
USING DELTA
TBLPROPERTIES(
  'delta.feature.allowColumnDefaults' = 'supported'
)
COMMENT 'Dimension estado - Star Schema - Sin SCD'
