-- %%
%sql
DROP TABLE IF EXISTS bootcamp_matias.raw.propiedades_bronze;
    
CREATE TABLE bootcamp_matias.raw.propiedades_bronze
  SELECT * FROM read_files(
    '/Volumes/bootcamp_matias/raw/archivos/properties_bronze.csv',
    format => 'csv',
    header => true
  )
  WHERE url LIKE 'https%'
